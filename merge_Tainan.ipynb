# %%
import pymongo
from pymongo import MongoClient
import datetime
import pprint
import re
from bson.objectid import ObjectId
import json

# %% [markdown]
# # Aipin

# %%
with open("D:/project/total_json/Aipin/TainanUniqueXY.json" , "r" , encoding="utf-8") as f:
    aipin = json.load(f)
#     pprint.pprint(merge[0])

# %% [markdown]
# # pixnet

# %%
with open("D:/project/total_json/pixnet/pixnet_tainan.json" , "r" , encoding="utf-8") as f:
    pixnet = json.load(f)

for i in aipin:
    for j in pixnet:
        try:
            if i['address'] == j['address'][0]:
                i['comment'].append({'content':j['content'],'url':j['url'],'message':j['comment']})
        except:
            pass

# %% [markdown]
# # mobile01

# %%
with open("D:/project/total_json/mobile01_tainan.json" , "r" , encoding="utf-8") as f:
    mobile = json.load(f)
mobile[0]
    
# for i in aipin:
#     for j in mobile:
#         if i['name'] == j['name']:
#             i['comment'].append({'content':j['content'],'url':j['url'],'message':j['message']})
# Out:
# {'comment': {'author_id': '',
#   'click': '8,602',
#   'content': '黑美人肉燥飯、魚丸湯\n\n\n\n台南街頭賣肉燥飯、魚丸湯的不勝枚舉，光是從東門陸橋到府前路1段上就有圓環邊靠大同路的無名、府前路一段上的阿和肉燥飯、黑美人肉燥飯、府前魯肉飯，其中位在府前路1段與萬昌街口的黑美人，則以自然健康為訴求。\n\n\n\n\n\n\n店面風格平實簡單，兩個店面一邊是廚房跟辦公區，另一邊則是用餐區。\n\n\n\n\n牆上除了價目表外，還可看到像統一食品、味丹企業高層的贈字，黑美人老闆薛征雄講究養生，曾研習漢醫，店內從醬油、麻油、花生油、辣椒醬到豆瓣醬等調味料都是自製的，貼上了店名，也有在販售。\n\n\n\n\n停好車走進店裡就聞到那種煮著肉燥、魚丸湯的香氣，在這種雨水帶來了涼意的日子裡益發明顯，點了肉燥飯、綜合湯，還來了盤醉牛肉$100，牛肉先用花雕酒浸泡再冷藏，酒味香濃。\n\n\n\n\n肉燥飯$20，融合肥瘦兩種部位的三層滷肉，用自釀醬油滷煮。\n\n\n\n\n綜合湯$60，裡面有魚皮、魚丸跟燕餃。黑美人的肉燥飯吃來較不會有那種傳統店家吃完肉燥飯會黏嘴的感覺，湯頭則是爽口帶點微甘。\n\n\n\n\n價目表。',
#   'date': '2012-05-23T18:02:39+08:00',
#   'message': ['推魯蛋,魯的很透....\n倫敦男孩 wrote:\n\n黑美人肉燥飯、魚丸湯...(恕刪)',
#    '倫敦男孩 wrote:\n\n黑美人肉燥飯、魚丸湯...(恕刪)\n\n\n這間好吃.但不起眼.往往都左轉去進福才想起來要吃黑美人',
#    '肉燥飯、醉牛肉的風味不錯,但相比醉牛肉我較愛醉雞的口感',
#    '今天去了只看到外牆掛的招牌,但找不到店舖',
#    '店裡只剩下賣調味料\n\n所有東西東不賣了!!\n\n超級想念的\n\n有人知道為什麼嗎???',
#    'sw7 wrote:\n\n店裡只剩下賣調味料所...(恕刪)\n\n\n因為老闆娘身體不好需要靜養 所以應該短時間內不會再營業了',
#    '真的是太可惜了\n倫敦男孩 wrote:\n\n黑美人肉燥飯、魚丸湯...(恕刪)',
# ...

# %%
#url.name.content.message
mobilelist=[{'name':i['name'],'url':i['comment']['url'],'content':i['comment']['content'],
             'message':i['comment']['message']} for i in mobile]

# %%
mobilelist[0]
for i in aipin:
    for j in mobilelist:
        try:
            if i['name'] == j['name']:
                i['comment'].append({'content':j['content'],'url':j['url'],'message':j['message']})
        except:
            pass

# %%
aipin[1]['comment']
# Out:
# [{'click': 1566,
#   'content': '----------------------------------------------------------------原文:【台南．東區】深藍咖啡館，號稱蛋糕界LV千層蛋糕及大人口味黑森林蛋糕，早茶開始就在當貴婦，普普時尚風格超像在藝文咖啡館!!!@女子的休假計劃FB:https://www.facebook.com/GoEatPlay/--------------------------------------------------------------自從在新加坡吃到好吃的LadyM就喜歡上那香嫩蛋皮裡裏上慕斯香甜滋味聽說台南有很厲害號稱蛋糕界LV的千層蛋糕就選了早茶時段前來一進門冷氣還蠻強的冰櫃及透明窗上都結上一層水氣店內呈現的普普風格給人現代時尚感一致性的水藍及白色系列為設計主軸非常有設計感、空間寬敞不自覺有點來到藝文咖啡館外帶盒也是普普圓點風格在2015年獲得紅點大賞GoodDesign不管是送禮或是自已提回家吃都非常氣派早茶時段蛋糕不多不過還是有LV栗子千層蛋糕再加碼挑了我最愛吃的黑森林蛋糕早茶．蛋糕$230Am8:00~12:00提供一份任選蛋糕+一壺茶黑森林蛋糕$100荔汁白茶選用美國有機茶，不含咖啡因不過茶包泡出的茶味不香沒有荔汁味水味多於茶味有點失望黑森林蛋糕表層酒漬過後黑櫻桃配上微苦巧克力片底層慕絲跟層層堆疊濕潤蛋糕體奶油就如空氣感柔順用湯匙挖至底層絕妙的大人成熟滋味，非常好吃!!!!栗子千層蛋糕網友號稱蛋糕界LV的千層蛋糕首先高度跟薄度另我忍不住數了一下聽說店家已經厲害到可以製成40多層唷!!!細緻柔順法國精選栗子熬煮成醬舖於表層另將奶油及香甜栗子一層一層費工的舖在每一片蛋皮上可能放在冰櫃太久蛋皮略硬，有點可惜--------------------------------------結論:要挑不是早午茶時段前來吃千層蛋糕，較為新鮮現做服務態度挺好的很認真介紹-------------------------------深藍咖啡館網址地址:台南市府連東路55號電話:06-2387722營業時間：週一至週日Am8:00~20:00/★咖啡/茶/飲品/蛋糕✔免服務費/無限時/插座/WIFIx低銷一份餐點檢視較大的地圖',
# ...

# %% [markdown]
# # ptt

# %%
with open("D:/project/total_json/ptt/ptt_tainan_address.json" , "r" , encoding="utf-8") as f:
    ptt_add = json.load(f)
    
for i in aipin:
    for j in ptt_add:
        if i['name'] == j['name']:
            i['comment'].append({'content':j['constent'],'url':j['url'],'message':j['comments']})

# %%
with open("D:/project/total_json/ptt/ptt_tainan_tel.json" , "r" , encoding="utf-8") as f:
    ptt_tel = json.load(f)
    
for i in aipin:
    for j in ptt_tel:
        if i['name'] == j['name']:
            i['comment'].append({'content':j['constent'],'url':j['url'],'message':j['comments']})

# %%
with open("D:/project/total_json/ptt/ptt_tainan.json" , "r" , encoding="utf-8") as f:
    ptt = json.load(f)
#     pprint.pprint(pttdata[0])
for i in aipin:
    for j in ptt:
        if i['name'] == j['name']:
            i['comment'].append({'content':j['constent'],'url':j['url'],'message':j['comments']})

# %% [markdown]
# # 寫出Tainan_final.json

# %%
with open("D:/project/total_json/Tainan_final.json" , "w" , encoding="utf-8") as f:
    json.dump(aipin, f)
